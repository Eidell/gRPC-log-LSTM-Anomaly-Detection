# %%
import json
import pandas as pd

# Load data from JSON file
with open('data.json') as f:
    data = json.load(f)

# Convert data to pandas DataFrame
df = pd.DataFrame(data)

# %%
print(df.columns)
# Out:
# Index(['unix_timestamp', 'requestSize', 'responseSize', 'requestMethod',
#        'latency', 'requestUrl', 'status', 'source_app'],
#       dtype='object')

# %%
# Convert the unix_timestamp to datetime and set it as the index
df['unix_timestamp'] = pd.to_datetime(df['unix_timestamp'], unit='ms')
df.set_index('unix_timestamp', inplace=True)

# Convert categorical features to one-hot encoded format
df = pd.get_dummies(df, columns=['requestUrl', 'status', 'source_app','requestMethod'])

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                         requestSize responseSize    latency  \
# unix_timestamp
# 2023-04-14 10:48:32.528         777         1675  0.0050307
# 2023-04-14 10:48:32.587         906         1551  0.0016767
# 2023-04-14 10:48:32.592         765         1675  0.0051266
# 2023-04-14 10:48:34.756         777         1676  0.0172641
# 2023-04-14 10:48:35.636         813         1676  0.0430453
# ...                             ...          ...        ...
# 2023-04-14 10:51:52.837         723         1501   0.702694
# 2023-04-14 10:51:52.839         723         1603  0.7010326
# 2023-04-14 10:51:53.287         712         1778  0.0649508
# 2023-04-14 10:51:53.355         723         1619  0.1853119
# 2023-04-14 10:51:53.543         825         1663  0.0049108
#
#                          requestUrl_http://adservice:9555/hipstershop.AdService/GetAds  \
# unix_timestamp
# 2023-04-14 10:48:32.528                                                  0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the numerical features
scaler = MinMaxScaler()
df[["latency", "requestSize", "responseSize"]] = scaler.fit_transform(df[["latency", "requestSize", "responseSize"]])

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                          requestSize  responseSize   latency  \
# unix_timestamp
# 2023-04-14 10:48:32.528     0.203431      0.121212  0.004739
# 2023-04-14 10:48:32.587     0.519608      0.035813  0.001297
# 2023-04-14 10:48:32.592     0.174020      0.121212  0.004838
# 2023-04-14 10:48:34.756     0.203431      0.121901  0.017295
# 2023-04-14 10:48:35.636     0.291667      0.121901  0.043756
# ...                              ...           ...       ...
# 2023-04-14 10:51:52.837     0.071078      0.001377  0.720797
# 2023-04-14 10:51:52.839     0.071078      0.071625  0.719092
# 2023-04-14 10:51:53.287     0.044118      0.192149  0.066239
# 2023-04-14 10:51:53.355     0.071078      0.082645  0.189774
# 2023-04-14 10:51:53.543     0.321078      0.112948  0.004616
#
#                          requestUrl_http://adservice:9555/hipstershop.AdService/GetAds  \
# unix_timestamp
# 2023-04-14 10:48:32.528                                                  0
# ...

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Select features to use for anomaly detection
features = ['latency',
            'requestMethod',
            'requestSize',
            'responseSize',
            'requestUrl',
            'status',
            'source_app']

# Rescale the data using the training data

scaler = StandardScaler()
train_size = int(len(df) * 0.95)
train = df[:train_size][features]
scaler.fit(train)
df[features] = scaler.transform(df[features])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 17>()
#      15 scaler = StandardScaler()
#      16 train_size = int(len(df) * 0.95)
# ---> 17 train = df[:train_size][features]
#      18 scaler.fit(train)
#      19 df[features] = scaler.transform(df[features])
#
# File /opt/software/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/software/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# Split data into subsequences
TIME_STEPS = 30
X, y = [], []
for i in range(len(df) - TIME_STEPS):
    v = df.iloc[i:(i + TIME_STEPS)][features].values
    X.append(v)
    y.append(v[-1])
X = np.array(X)
y = np.array(y)

# %%
from tensorflow import keras

# Build LSTM autoencoder model
model = keras.Sequential()
model.add(keras.layers.LSTM(units=64, input_shape=(X.shape[1], X.shape[2])))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.RepeatVector(n=X.shape[1]))
model.add(keras.layers.LSTM(units=64, return_sequences=True))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.TimeDistributed(keras.layers.Dense(units=X.shape[2])))
model.compile(loss='mae', optimizer='adam')

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32, validation_split=0.1, shuffle=False)
# Out:
# 2023-04-18 13:32:23.844230: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-18 13:32:25.315827: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [5], in <cell line: 14>()
#      11 model.compile(loss='mae', optimizer='adam')
# ...
